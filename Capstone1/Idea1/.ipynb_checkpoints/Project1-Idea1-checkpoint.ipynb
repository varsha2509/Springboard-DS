# %% [markdown]
# #### Idea1: Can we improve yield prediction for different crops across different counties in the US? Understanding crop yield data is essential to ensure food security and climate change, and changes in weather patterns are affecting crop yield throughout. The goal of this project is to be able to predict the yield of crops in the US using publicly available datasets on weather, soil quality, amount of crop irrigated and other features.
#
# #### This project predicts the yield of wheat in different counties in the US. The datasets for this project is from https://github.com/aerialintel/data-science-exercise and includes data for both 2013 and 2014.
#
#
# #### The 2013 dataset is loaded here.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import descartes
import geopandas as gpd
from shapely.geometry import Point, Polygon

# %matplotlib inline

# %%
#### Reading in dataset

# %%
df1_2013 = pd.read_csv('Wheat2013.csv',header=0)

# %%
df1_2013['Date'].unique().count()

# %%
df1_2013.groupby(['State'])['Yield'].describe()
# Out:
#               count       mean        std   min   25%   50%   75%   max
# State
# Kansas      55800.0  33.702000  11.566218  12.1  25.8  32.4  44.8  59.0
# Montana     19480.0  43.481899   9.318131  32.3  37.8  40.9  48.4  68.5
# Oklahoma    33941.0  20.059362  10.560151  10.2  14.0  16.5  22.0  69.0
# Texas       58228.0  29.242950  16.870902   9.0  14.4  24.2  42.4  72.2
# Washington  10044.0  46.766667  11.904840  31.3  35.7  43.7  52.4  66.0

# %% [markdown]
# ### Exploring data in Texas

# %%
df_Tex= df1_2013[df1_2013['State'] == 'Texas']

# %%
df_Tex.groupby('CountyName')['Yield'].describe()
# Out:
#                 count  mean           std   min   25%   50%   75%   max
# CountyName
# Archer         1116.0  13.1  2.434700e-13  13.1  13.1  13.1  13.1  13.1
# Armstrong      1116.0  13.8  2.736816e-13  13.8  13.8  13.8  13.8  13.8
# Bailey         1116.0  21.4  2.843445e-13  21.4  21.4  21.4  21.4  21.4
# Baylor         1116.0  16.5  0.000000e+00  16.5  16.5  16.5  16.5  16.5
# Bell           1108.0  52.2  9.738831e-13  52.2  52.2  52.2  52.2  52.2
# Bexar          1116.0  31.5  0.000000e+00  31.5  31.5  31.5  31.5  31.5
# Bosque          750.0  27.1  7.821186e-14  27.1  27.1  27.1  27.1  27.1
# Brown           388.0  13.6  3.201571e-14  13.6  13.6  13.6  13.6  13.6
# Callahan       1116.0  11.5  0.000000e+00  11.5  11.5  11.5  11.5  11.5
# Carson         1116.0  24.2  4.691685e-13  24.2  24.2  24.2  24.2  24.2
# Childress      1116.0   9.6  1.990412e-13   9.6   9.6   9.6   9.6   9.6
# Clay           1116.0  23.5  0.000000e+00  23.5  23.5  23.5  23.5  23.5
# Coke           1116.0  15.2  3.145561e-13  15.2  15.2  15.2  15.2  15.2
# Coleman         935.0  13.2  1.599577e-13  13.2  13.2  13.2  13.2  13.2
# Collin         1116.0  63.3  1.322202e-12  63.3  63.3  63.3  63.3  63.3
# Collingsworth  1116.0  17.8  3.732022e-13  17.8  17.8  17.8  17.8  17.8
# Concho         1116.0  25.3  4.798314e-13  25.3  25.3  25.3  25.3  25.3
# Cooke          1116.0  42.4  8.672508e-13  42.4  42.4  42.4  42.4  42.4
# Coryell        1108.0  33.8  7.819500e-14  33.8  33.8  33.8  33.8  33.8
# Cottle         1116.0   9.1  1.919325e-13   9.1   9.1   9.1   9.1   9.1
# Dallam         1107.0  54.1  9.881008e-13  54.1  54.1  54.1  54.1  54.1
# Deaf Smith     1116.0  41.7  5.047115e-13  41.7  41.7  41.7  41.7  41.7
# Delta           191.0  72.2  2.137230e-13  72.2  72.2  72.2  72.2  72.2
# Denton         1116.0  37.6  7.819474e-13  37.6  37.6  37.6  37.6  37.6
# Dickens        1116.0  11.2  1.670524e-13  11.2  11.2  11.2  11.2  11.2
# Donley         1116.0  11.6  2.292528e-13  11.6  11.6  11.6  11.6  11.6
# Eastland        756.0   9.0  0.000000e+00   9.0   9.0   9.0   9.0   9.0
# Ellis          1112.0  54.9  1.002316e-12  54.9  54.9  54.9  54.9  54.9
# Falls           935.0  55.3  7.393599e-13  55.3  55.3  55.3  55.3  55.3
# Fannin          566.0  58.5  0.000000e+00  58.5  58.5  58.5  58.5  58.5
# Floyd          1116.0  17.0  0.000000e+00  17.0  17.0  17.0  17.0  17.0
# Foard          1116.0  20.4  2.239213e-13  20.4  20.4  20.4  20.4  20.4
# Frio           1116.0  53.5  0.000000e+00  53.5  53.5  53.5  53.5  53.5
# Gillespie       918.0  14.0  0.000000e+00  14.0  14.0  14.0  14.0  14.0
# Gray           1116.0  17.3  3.625393e-13  17.3  17.3  17.3  17.3  17.3
# Grayson        1116.0  63.2  1.322202e-12  63.2  63.2  63.2  63.2  63.2
# Guadalupe      1116.0  29.8  4.620598e-13  29.8  29.8  29.8  29.8  29.8
# Hamilton        386.0  27.0  0.000000e+00  27.0  27.0  27.0  27.0  27.0
# Hardeman       1116.0  11.6  2.292528e-13  11.6  11.6  11.6  11.6  11.6
# Haskell        1116.0  15.7  3.269962e-13  15.7  15.7  15.7  15.7  15.7
# Hemphill       1098.0  12.2  2.043741e-13  12.2  12.2  12.2  12.2  12.2
# Hill           1116.0  49.4  9.454455e-13  49.4  49.4  49.4  49.4  49.4
# Hunt           1116.0  64.4  4.265168e-13  64.4  64.4  64.4  64.4  64.4
# Hutchinson     1116.0  35.7  9.952058e-14  35.7  35.7  35.7  35.7  35.7
# Jim Wells       186.0  34.8  1.139937e-13  34.8  34.8  34.8  34.8  34.8
# Johnson         933.0  37.5  0.000000e+00  37.5  37.5  37.5  37.5  37.5
# Jones          1116.0  14.9  2.310299e-13  14.9  14.9  14.9  14.9  14.9
# Kaufman        1116.0  46.2  7.392957e-13  46.2  46.2  46.2  46.2  46.2
# Knox           1113.0  14.4  2.541332e-13  14.4  14.4  14.4  14.4  14.4
# Lamar             7.0  52.2  7.674739e-15  52.2  52.2  52.2  52.2  52.2
# Lampasas       1116.0  27.2  4.976029e-13  27.2  27.2  27.2  27.2  27.2
# Lipscomb       1098.0  29.0  0.000000e+00  29.0  29.0  29.0  29.0  29.0
# Lubbock        1116.0  17.6  2.843445e-14  17.6  17.6  17.6  17.6  17.6
# Lynn           1116.0  22.9  3.589850e-13  22.9  22.9  22.9  22.9  22.9
# Mason           930.0  44.0  0.000000e+00  44.0  44.0  44.0  44.0  44.0
# McCulloch       935.0  11.2  5.865115e-14  11.2  11.2  11.2  11.2  11.2
# McLennan       1116.0  47.9  9.312283e-13  47.9  47.9  47.9  47.9  47.9
# Medina         1116.0  31.9  6.682096e-13  31.9  31.9  31.9  31.9  31.9
# Milam           376.0  51.6  1.422979e-14  51.6  51.6  51.6  51.6  51.6

# %% [markdown]
# ### Exploring data in Washington

# %%
df_Wash = df1_2013[df1_2013['State'] == 'Washington']

# %%
df_Wash.shape
# Out:
# (10044, 27)

# %%
df_Wash.groupby('CountyName')['Yield'].describe()
# Out:
#              count  mean           std   min   25%   50%   75%   max
# CountyName
# Adams       1116.0  35.7  9.952058e-14  35.7  35.7  35.7  35.7  35.7
# Asotin      1116.0  52.4  9.738800e-13  52.4  52.4  52.4  52.4  52.4
# Columbia    1116.0  66.0  0.000000e+00  66.0  66.0  66.0  66.0  66.0
# Douglas     1116.0  35.3  6.397752e-14  35.3  35.3  35.3  35.3  35.3
# Franklin    1116.0  31.3  2.985617e-13  31.3  31.3  31.3  31.3  31.3
# Garfield    1116.0  65.6  2.985617e-13  65.6  65.6  65.6  65.6  65.6
# Grant       1116.0  42.9  8.672508e-13  42.9  42.9  42.9  42.9  42.9
# Klickitat   1116.0  43.7  6.113407e-13  43.7  43.7  43.7  43.7  43.7
# Lincoln     1116.0  48.0  0.000000e+00  48.0  48.0  48.0  48.0  48.0

# %% [markdown]
# ### Plotting all the datapoints on a basemap

# %%
usa = gpd.read_file('./states_21basic/states.shp')

# %%
usa.head()
# Out:
#      STATE_NAME  DRAWSEQ STATE_FIPS          SUB_REGION STATE_ABBR  \
# 0        Hawaii        1         15             Pacific         HI
# 1    Washington        2         53             Pacific         WA
# 2       Montana        3         30            Mountain         MT
# 3         Maine        4         23         New England         ME
# 4  North Dakota        5         38  West North Central         ND
#
#                                             geometry
# 0  MULTIPOLYGON (((-160.07380 22.00418, -160.0497...
# 1  MULTIPOLYGON (((-122.40202 48.22522, -122.4628...
# 2  POLYGON ((-111.47543 44.70216, -111.48080 44.6...
# 3  MULTIPOLYGON (((-69.77728 44.07415, -69.85993 ...
# 4  POLYGON ((-98.73044 45.93827, -99.00683 45.939...

# %%
usa.drop(usa[usa['STATE_NAME'] =='Alaska'].index, inplace=True)

# %%
usa.drop(usa[usa['STATE_NAME'] =='Hawaii'].index, inplace=True)

# %%
fig, ax = plt.subplots(figsize = (30,30))
usa.plot(ax=ax)

# %%
#Set the Coordinate Reference System for the dataframe

# %%
crs = {'init': 'epsg:4326'}

# %%
geometry = [Point(xy) for xy in zip(df1_2013['Longitude'], df1_2013['Latitude'])]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-1be74e10fa49> in <module>
#       1 geometry = [Point(xy) for xy in zip(df1_2013['Longitude'], df1_2013['Latitude'])]
# ----> 2 geometry.length
#
# AttributeError: 'list' object has no attribute 'length'

# %%
len(geometry)
# Out:
# 177493

# %%
geo_df = gpd.GeoDataFrame(df1_2013, crs = crs, geometry = geometry)

# %%
geo_df.head()
# Out:
#   CountyName       State   Latitude   Longitude             Date  \
# 0      Adams  Washington  46.811686 -118.695237  11/30/2013 0:00
# 1      Adams  Washington  46.929839 -118.352109  11/30/2013 0:00
# 2      Adams  Washington  47.006888 -118.510160  11/30/2013 0:00
# 3      Adams  Washington  47.162342 -118.699677  11/30/2013 0:00
# 4      Adams  Washington  47.157512 -118.434056  11/30/2013 0:00
#
#    apparentTemperatureMax  apparentTemperatureMin  cloudCover  dewPoint  \
# 0                   35.70                   20.85        0.00     29.53
# 1                   35.10                   26.92        0.00     29.77
# 2                   33.38                   26.95        0.00     29.36
# 3                   28.05                   25.93        0.91     29.47
# 4                   28.83                   25.98        0.91     29.86
#
#    humidity  ...  pressure  temperatureMax  temperatureMin  visibility  \
# 0      0.91  ...   1027.13           35.70           27.48        2.46
# 1      0.93  ...   1026.87           35.10           26.92        2.83
# 2      0.94  ...   1026.88           33.38           26.95        2.95
# 3      0.94  ...   1026.37           33.19           27.17        2.89
# 4      0.94  ...   1026.19           33.85           27.07        2.97
#
#    windBearing  windSpeed        NDVI  DayInSeason  Yield  \
# 0          214       1.18  134.110657            0   35.7
# 1          166       1.01  131.506592            0   35.7
# 2          158       1.03  131.472946            0   35.7
# 3          153       1.84  131.288300            0   35.7
# 4          156       1.85  131.288300            0   35.7
#
#                       geometry
# 0  POINT (-118.69524 46.81169)
# 1  POINT (-118.35211 46.92984)
# 2  POINT (-118.51016 47.00689)
# 3  POINT (-118.69968 47.16234)
# 4  POINT (-118.43406 47.15751)
#
# [5 rows x 27 columns]

# %%
fig, ax = plt.subplots(figsize = (30,30))
usa.plot(ax=ax, alpha = 0.1, color='grey')
geo_df[geo_df['State'] == 'Washington'].plot(ax = ax, color = 'blue', marker = 'o', markersize = 10)

geo_df[geo_df['State'] == 'Texas'].plot(ax = ax, color = 'darkgrey', marker = "^", markersize = 10)

geo_df[geo_df['State'] == 'Montana'].plot(ax = ax, color = 'black', marker = "*", markersize = 10)

geo_df[geo_df['State'] == 'Kansas'].plot(ax = ax, color = 'green', marker = ".", markersize = 10)

geo_df[geo_df['State'] == 'Texas'].plot(ax = ax, color = 'red', marker = "+", markersize = 10)
