# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import descartes
import geopandas as gpd
from shapely.geometry import Point, Polygon
from shapely.ops import nearest_points

import seaborn as sns

from mpl_toolkits.axes_grid1 import make_axes_locatable

import math

from scipy.stats import pearsonr

import time


from scipy.stats import boxcox

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE


from sklearn.linear_model import RidgeCV, LassoCV, Ridge, Lasso


from patsy import dmatrices
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor


from matplotlib import cm

import matplotlib.lines as mlines

import warnings
warnings.filterwarnings("ignore")

sns.set(style = 'whitegrid')
sns.set_palette('bright')
# %matplotlib inline

# %%
## Reading input data
BC_clustered = pd.read_csv("../Data/BC_input_clustered.csv")
NO2_clustered = pd.read_csv("../Data/NO2_input_clustered.csv")

# %%
#Convert columns to non-numeric 
BC = BC_clustered._get_numeric_data() #drop non-numeric cols
NO2 = NO2_clustered._get_numeric_data() #drop non-numeric cols

# %%
# Drop first column
BC.drop(BC.columns[0], axis=1, inplace=True)
NO2.drop(NO2.columns[0], axis=1, inplace=True)

# %% [markdown]
# <b> <font size = 5> Correlation coefficient and Testing the Significance of the Correlation Coefficient </b> </font>

# %% [markdown]
# We perform a hypothesis test of the “significance of the correlation coefficient” to decide whether the linear relationship in the data is strong enough to use to model the relationship. Since we have data for the entire population, we can use the population correlation coefficient.

# %% [markdown]
# Null Hypothesis: H$_{0}$: ρ = 0
#
# Alternate Hypothesis: H$_1$: ρ ≠ 0
#
#
# ρ = population correlation coefficient

# %% [markdown]
# Null Hypothesis H$_0$: The population correlation coefficient <b>is not</b> significantly different from zero. There <b>is not</b> a significant linear relationship(correlation) between x and y in the population.
#
# Alternate Hypothesis H$_1$: The population correlation coefficient is significantly different from zero. There <b>is a significant linear relationship</b> (correlation) between x and y in the population.

# %% [markdown]
# <font size = 4> <b> Estimating the Correlation Coefficient (r), 95% Confidence Interval for r,  R2 and p-value for the BC dataset </b> </font>

# %%
import pingouin as pg
BC_pearsonr = pg.pairwise_corr(BC, method='pearson', padjust = 'none' )

# %%
BC_pearsonr.head(100)
# Out:
#                                    X                                  Y  \
# 0                           BC Value   10457411-Manufacturing-high_dist
# 1                           BC Value      10457711-Foundaries-high_dist
# 2                           BC Value      10460511-Retail-Res-high_dist
# 3                           BC Value      10469511-Retail-Res-high_dist
# 4                           BC Value   10476711-Manufacturing-high_dist
# ..                               ...                                ...
# 95  10457411-Manufacturing-high_dist      15941111-Retail-Res-high_dist
# 96  10457411-Manufacturing-high_dist             168411-Waste-high_dist
# 97  10457411-Manufacturing-high_dist      17244511-Retail-Res-high_dist
# 98  10457411-Manufacturing-high_dist            18134411-Misc-high_dist
# 99  10457411-Manufacturing-high_dist  18135311-Transportation-high_dist
#
#      method       tail      n         r           CI95%        r2    adj_r2  \
# 0   pearson  two-sided  13379 -0.330193  [-0.35, -0.32]  0.109027  0.108894
# 1   pearson  two-sided  13379  0.336358    [0.32, 0.35]  0.113136  0.113004
# 2   pearson  two-sided  13379 -0.292290  [-0.31, -0.28]  0.085433  0.085297
# 3   pearson  two-sided  13379 -0.364821  [-0.38, -0.35]  0.133094  0.132965
# 4   pearson  two-sided  13379  0.077335    [0.06, 0.09]  0.005981  0.005832
# ..      ...        ...    ...       ...             ...       ...       ...
# 95  pearson  two-sided  13379  0.984717    [0.98, 0.99]  0.969667  0.969662
# 96  pearson  two-sided  13379  0.989539    [0.99, 0.99]  0.979188  0.979185
# 97  pearson  two-sided  13379 -0.992516  [-0.99, -0.99]  0.985088  0.985085
# 98  pearson  two-sided  13379  0.999905      [1.0, 1.0]  0.999811  0.999811
# 99  pearson  two-sided  13379  0.984813    [0.98, 0.99]  0.969856  0.969852
#
#            z          p-unc        BF10  power
# 0  -0.343045   0.000000e+00         inf    1.0
# 1   0.349980   0.000000e+00         inf    1.0
# 2  -0.301068  9.144344e-262  2.556e+257    1.0
# 3  -0.382436   0.000000e+00         inf    1.0
# 4   0.077490   3.313170e-19   2.865e+15    1.0
# ..       ...            ...         ...    ...
# 95  2.433232   0.000000e+00         inf    1.0
# 96  2.624017   0.000000e+00         inf    1.0
# 97 -2.792179   0.000000e+00         inf    1.0
# 98  4.979440   0.000000e+00         inf    1.0
# 99  2.436410   0.000000e+00         inf    1.0
#
# [100 rows x 13 columns]

# %%
BC_pearsonr_BC = BC_pearsonr[BC_pearsonr.X == 'BC Value']

# %%
BC_pearsonr_BC.head(50)
# Out:
#            X                                  Y   method       tail      n  \
# 0   BC Value   10457411-Manufacturing-high_dist  pearson  two-sided  13379
# 1   BC Value      10457711-Foundaries-high_dist  pearson  two-sided  13379
# 2   BC Value      10460511-Retail-Res-high_dist  pearson  two-sided  13379
# 3   BC Value      10469511-Retail-Res-high_dist  pearson  two-sided  13379
# 4   BC Value   10476711-Manufacturing-high_dist  pearson  two-sided  13379
# 5   BC Value    10510811-AsphaltPlant-high_dist  pearson  two-sided  13379
# 6   BC Value      10517111-Retail-Res-high_dist  pearson  two-sided  13379
# 7   BC Value   10518911-ConcretePlant-high_dist  pearson  two-sided  13379
# 8   BC Value            10707511-EGen-high_dist  pearson  two-sided  13379
# 9   BC Value           10708011-Waste-high_dist  pearson  two-sided  13379
# 10  BC Value   10708111-Manufacturing-high_dist  pearson  two-sided  13379
# 11  BC Value       1106211-Retail-Res-high_dist  pearson  two-sided  13379
# 12  BC Value              136511-EGen-high_dist  pearson  two-sided  13379
# 13  BC Value        137211-Retail-Res-high_dist  pearson  two-sided  13379
# 14  BC Value      13761011-Retail-Res-high_dist  pearson  two-sided  13379
# 15  BC Value   13801611-Manufacturing-high_dist  pearson  two-sided  13379
# 16  BC Value        138911-AutoRepair-high_dist  pearson  two-sided  13379
# 17  BC Value     140211-Manufacturing-high_dist  pearson  two-sided  13379
# 18  BC Value      14122011-Retail-Res-high_dist  pearson  two-sided  13379
# 19  BC Value        141411-Retail-Res-high_dist  pearson  two-sided  13379
# 20  BC Value      14241511-Retail-Res-high_dist  pearson  two-sided  13379
# 21  BC Value   14267411-Manufacturing-high_dist  pearson  two-sided  13379
# 22  BC Value      14292411-Retail-Res-high_dist  pearson  two-sided  13379
# 23  BC Value       14318611-FoodPlant-high_dist  pearson  two-sided  13379
# 24  BC Value       15713811-FoodPlant-high_dist  pearson  two-sided  13379
# 25  BC Value      15714511-AutoRepair-high_dist  pearson  two-sided  13379
# 26  BC Value      15745711-Retail-Res-high_dist  pearson  two-sided  13379
# 27  BC Value       15756011-FoodPlant-high_dist  pearson  two-sided  13379
# 28  BC Value      15941111-Retail-Res-high_dist  pearson  two-sided  13379
# 29  BC Value             168411-Waste-high_dist  pearson  two-sided  13379
# 30  BC Value      17244511-Retail-Res-high_dist  pearson  two-sided  13379
# 31  BC Value            18134411-Misc-high_dist  pearson  two-sided  13379
# 32  BC Value  18135311-Transportation-high_dist  pearson  two-sided  13379
# 33  BC Value      18492711-Retail-Res-high_dist  pearson  two-sided  13379
# 34  BC Value           18782611-Waste-high_dist  pearson  two-sided  13379
# 35  BC Value     193511-ConcretePlant-high_dist  pearson  two-sided  13379
# 36  BC Value        203711-Retail-Res-high_dist  pearson  two-sided  13379
# 37  BC Value        310211-Retail-Res-high_dist  pearson  two-sided  13379
# 38  BC Value        310411-Retail-Res-high_dist  pearson  two-sided  13379
# 39  BC Value        338911-Retail-Res-high_dist  pearson  two-sided  13379
# 40  BC Value         340611-FoodPlant-high_dist  pearson  two-sided  13379
# 41  BC Value         343011-FoodPlant-high_dist  pearson  two-sided  13379
# 42  BC Value          375111-Eateries-high_dist  pearson  two-sided  13379
# 43  BC Value              379511-WWTP-high_dist  pearson  two-sided  13379
# 44  BC Value     380611-Manufacturing-high_dist  pearson  two-sided  13379
# 45  BC Value        382111-Foundaries-high_dist  pearson  two-sided  13379
# 46  BC Value              382911-Misc-high_dist  pearson  two-sided  13379
# 47  BC Value       3963311-Foundaries-high_dist  pearson  two-sided  13379
# 48  BC Value    3963411-Manufacturing-high_dist  pearson  two-sided  13379
# 49  BC Value        405311-Foundaries-high_dist  pearson  two-sided  13379
#
#            r           CI95%        r2    adj_r2         z          p-unc  \
# 0  -0.330193  [-0.35, -0.32]  0.109027  0.108894 -0.343045   0.000000e+00
# 1   0.336358    [0.32, 0.35]  0.113136  0.113004  0.349980   0.000000e+00
# 2  -0.292290  [-0.31, -0.28]  0.085433  0.085297 -0.301068  9.144344e-262
# 3  -0.364821  [-0.38, -0.35]  0.133094  0.132965 -0.382436   0.000000e+00
# 4   0.077335    [0.06, 0.09]  0.005981  0.005832  0.077490   3.313170e-19
# 5   0.334598    [0.32, 0.35]  0.111956  0.111823  0.347997   0.000000e+00
# 6  -0.293197  [-0.31, -0.28]  0.085965  0.085828 -0.302061  1.871776e-263
# 7  -0.347513  [-0.36, -0.33]  0.120765  0.120634 -0.362612   0.000000e+00
# 8  -0.283185   [-0.3, -0.27]  0.080194  0.080056 -0.291142  3.708037e-245
# 9   0.329491    [0.31, 0.34]  0.108564  0.108431  0.342257   0.000000e+00
# 10  0.359497    [0.34, 0.37]  0.129238  0.129108  0.376308   0.000000e+00
# 11 -0.368070  [-0.38, -0.35]  0.135475  0.135346 -0.386189   0.000000e+00
# 12 -0.411847   [-0.43, -0.4]  0.169618  0.169494 -0.437833   0.000000e+00
# 13 -0.294929  [-0.31, -0.28]  0.086983  0.086846 -0.303956  1.076402e-266
# 14 -0.337105  [-0.35, -0.32]  0.113640  0.113507 -0.350823   0.000000e+00
# 15 -0.344212  [-0.36, -0.33]  0.118482  0.118350 -0.358863   0.000000e+00
# 16 -0.329871  [-0.34, -0.31]  0.108815  0.108682 -0.342684   0.000000e+00
# 17  0.364574    [0.35, 0.38]  0.132914  0.132784  0.382151   0.000000e+00
# 18  0.426807    [0.41, 0.44]  0.182164  0.182042  0.455986   0.000000e+00
# 17         inf    1.0
# 18         inf    1.0
# 19         inf    1.0
# 20         inf    1.0
# 21         inf    1.0
# 22         inf    1.0
# 23   4.32e+139    1.0
# 24         inf    1.0
# 25         inf    1.0
# 26  1.184e+273    1.0
# 27         inf    1.0
# 28  7.818e+304    1.0
# 29         inf    1.0
# 30         inf    1.0
# 31         inf    1.0
# 32         inf    1.0
# 33         inf    1.0
# 34         inf    1.0
# 35   2.775e+97    1.0
# 36         inf    1.0
# 37   1.601e+38    1.0
# 38  4.607e+132    1.0
# 39  6.009e+233    1.0
# 40         inf    1.0
# 41         inf    1.0
# 42         inf    1.0
# 43         inf    1.0
# 44  4.338e+299    1.0
# 45         inf    1.0
# 46         inf    1.0
# 47         inf    1.0
# 48         inf    1.0
# 49         inf    1.0

# %% [markdown]
# <font size = 4> <b> Determine the features that have a p-value that is above the level of signifiance alpha of 0.05 </b> </font>
#
# <font size = 2> We reject the alternative hypothesis and conclude that the null hypothesis is true in this case i.e. there is no statistical significance of the correlation coefficient </font>

# %%
BC_pearsonr_BC[BC_pearsonr_BC['p-unc'] >= 0.005 ]
# Out:
# Empty DataFrame
# Columns: [X, Y, method, tail, n, r, CI95%, r2, adj_r2, z, p-unc, BF10, power]
# Index: []

# %% [markdown]
# <font size = 4> <b> Estimating the Correlation Coefficient (r), 95% Confidence Interval for r,  R2 and p-value for the NO2 dataset </b> </font>

# %%
NO2_pearsonr = pg.pairwise_corr(NO2_clustered, method='pearson', padjust = 'none' )

# %%
NO2_pearsonr.head(100)
# Out:
#              X                                 Y   method       tail      n  \
# 0   Unnamed: 0                         NO2 Value  pearson  two-sided  13379
# 1   Unnamed: 0  10457511-Manufacturing-high_dist  pearson  two-sided  13379
# 2   Unnamed: 0     10460511-Retail-Res-high_dist  pearson  two-sided  13379
# 3   Unnamed: 0   10510811-AsphaltPlant-high_dist  pearson  two-sided  13379
# 4   Unnamed: 0     10517111-Retail-Res-high_dist  pearson  two-sided  13379
# ..         ...                               ...      ...        ...    ...
# 95   NO2 Value         375111-Eateries-high_dist  pearson  two-sided  13379
# 96   NO2 Value             379511-WWTP-high_dist  pearson  two-sided  13379
# 97   NO2 Value       382111-Foundaries-high_dist  pearson  two-sided  13379
# 98   NO2 Value             382911-Misc-high_dist  pearson  two-sided  13379
# 99   NO2 Value   3963411-Manufacturing-high_dist  pearson  two-sided  13379
#
#            r           CI95%        r2    adj_r2         z  p-unc BF10  power
# 0  -0.654154  [-0.66, -0.64]  0.427917  0.427831 -0.782525    0.0  inf    1.0
# 1   0.890677    [0.89, 0.89]  0.793306  0.793275  1.425193    0.0  inf    1.0
# 2   0.805265     [0.8, 0.81]  0.648451  0.648399  1.113411    0.0  inf    1.0
# 3  -0.770925  [-0.78, -0.76]  0.594326  0.594265 -1.022605    0.0  inf    1.0
# 4   0.799568    [0.79, 0.81]  0.639310  0.639256  1.097415    0.0  inf    1.0
# ..       ...             ...       ...       ...       ...    ...  ...    ...
# 95 -0.575978  [-0.59, -0.56]  0.331751  0.331651 -0.656424    0.0  inf    1.0
# 96 -0.591089   [-0.6, -0.58]  0.349386  0.349289 -0.679338    0.0  inf    1.0
# 97  0.594534    [0.58, 0.61]  0.353471  0.353374  0.684650    0.0  inf    1.0
# 98  0.627543    [0.62, 0.64]  0.393811  0.393720  0.737353    0.0  inf    1.0
# 99  0.572156    [0.56, 0.58]  0.327362  0.327262  0.650722    0.0  inf    1.0
#
# [100 rows x 13 columns]

# %%
NO2_pearsonr_NO2 = NO2_pearsonr[NO2_pearsonr.X == 'NO2 Value']

# %%
NO2_pearsonr_NO2.head(100)
# Out:
#              X                                 Y   method       tail      n  \
# 60   NO2 Value  10457511-Manufacturing-high_dist  pearson  two-sided  13379
# 61   NO2 Value     10460511-Retail-Res-high_dist  pearson  two-sided  13379
# 62   NO2 Value   10510811-AsphaltPlant-high_dist  pearson  two-sided  13379
# 63   NO2 Value     10517111-Retail-Res-high_dist  pearson  two-sided  13379
# 64   NO2 Value           10707511-EGen-high_dist  pearson  two-sided  13379
# 65   NO2 Value          10708011-Waste-high_dist  pearson  two-sided  13379
# 66   NO2 Value       127511-Retail-Res-high_dist  pearson  two-sided  13379
# 67   NO2 Value             136511-EGen-high_dist  pearson  two-sided  13379
# 68   NO2 Value     13761011-Retail-Res-high_dist  pearson  two-sided  13379
# 69   NO2 Value     13825511-Retail-Res-high_dist  pearson  two-sided  13379
# 70   NO2 Value  13983311-Manufacturing-high_dist  pearson  two-sided  13379
# 71   NO2 Value           13985611-Misc-high_dist  pearson  two-sided  13379
# 72   NO2 Value    140211-Manufacturing-high_dist  pearson  two-sided  13379
# 73   NO2 Value  14071611-Manufacturing-high_dist  pearson  two-sided  13379
# 74   NO2 Value     14122011-Retail-Res-high_dist  pearson  two-sided  13379
# 75   NO2 Value  14182811-Manufacturing-high_dist  pearson  two-sided  13379
# 76   NO2 Value  14267411-Manufacturing-high_dist  pearson  two-sided  13379
# 77   NO2 Value      14318611-FoodPlant-high_dist  pearson  two-sided  13379
# 78   NO2 Value     15721111-Retail-Res-high_dist  pearson  two-sided  13379
# 79   NO2 Value     15745711-Retail-Res-high_dist  pearson  two-sided  13379
# 80   NO2 Value           15974511-Misc-high_dist  pearson  two-sided  13379
# 81   NO2 Value           18132711-Misc-high_dist  pearson  two-sided  13379
# 82   NO2 Value     18133511-Retail-Res-high_dist  pearson  two-sided  13379
# 83   NO2 Value     18135811-Retail-Res-high_dist  pearson  two-sided  13379
# 84   NO2 Value     18495611-Retail-Res-high_dist  pearson  two-sided  13379
# 85   NO2 Value     18496511-Retail-Res-high_dist  pearson  two-sided  13379
# 86   NO2 Value     18697211-Retail-Res-high_dist  pearson  two-sided  13379
# 87   NO2 Value     18697911-Retail-Res-high_dist  pearson  two-sided  13379
# 88   NO2 Value       195711-AutoRepair-high_dist  pearson  two-sided  13379
# 89   NO2 Value       200611-Retail-Res-high_dist  pearson  two-sided  13379
# 90   NO2 Value             203811-WWTP-high_dist  pearson  two-sided  13379
# 91   NO2 Value       310211-Retail-Res-high_dist  pearson  two-sided  13379
# 92   NO2 Value       310411-Retail-Res-high_dist  pearson  two-sided  13379
# 93   NO2 Value       338911-Retail-Res-high_dist  pearson  two-sided  13379
# 94   NO2 Value        340611-FoodPlant-high_dist  pearson  two-sided  13379
# 95   NO2 Value         375111-Eateries-high_dist  pearson  two-sided  13379
# 96   NO2 Value             379511-WWTP-high_dist  pearson  two-sided  13379
# 97   NO2 Value       382111-Foundaries-high_dist  pearson  two-sided  13379
# 98   NO2 Value             382911-Misc-high_dist  pearson  two-sided  13379
# 99   NO2 Value   3963411-Manufacturing-high_dist  pearson  two-sided  13379
# 100  NO2 Value       405311-Foundaries-high_dist  pearson  two-sided  13379
# 101  NO2 Value   444911-Transportation-high_dist  pearson  two-sided  13379
# 102  NO2 Value    445511-Manufacturing-high_dist  pearson  two-sided  13379
# 103  NO2 Value       448011-Retail-Res-high_dist  pearson  two-sided  13379
# 104  NO2 Value   4955911-Manufacturing-high_dist  pearson  two-sided  13379
# 105  NO2 Value        512911-FoodPlant-high_dist  pearson  two-sided  13379
# 106  NO2 Value         771711-Eateries-high_dist  pearson  two-sided  13379
# 107  NO2 Value    773811-Manufacturing-high_dist  pearson  two-sided  13379
# 108  NO2 Value      7845611-Retail-Res-high_dist  pearson  two-sided  13379
# 109  NO2 Value        804911-FoodPlant-high_dist  pearson  two-sided  13379
# 110  NO2 Value     808611-AsphaltPlant-high_dist  pearson  two-sided  13379
# 111  NO2 Value        808811-FoodPlant-high_dist  pearson  two-sided  13379
# 112  NO2 Value                            Precip  pearson  two-sided  13379
# 113  NO2 Value                         Radiation  pearson  two-sided  13379
# 114  NO2 Value                           Maxtemp  pearson  two-sided  13379
# 115  NO2 Value                           Mintemp  pearson  two-sided  13379
# 116  NO2 Value                          Pressure  pearson  two-sided  13379
# 117  NO2 Value                              Dist  pearson  two-sided  13379
# 118  NO2 Value              number_intersections  pearson  two-sided  13379
#
#             r           CI95%        r2    adj_r2         z          p-unc  \
# 60  -0.612269   [-0.62, -0.6]  0.374873  0.374780 -0.712543   0.000000e+00
# 61  -0.544293  [-0.56, -0.53]  0.296255  0.296150 -0.610236   0.000000e+00
# 62   0.558601    [0.55, 0.57]  0.312035  0.311932  0.630797   0.000000e+00
# 63  -0.544155  [-0.56, -0.53]  0.296105  0.296000 -0.610040   0.000000e+00
# 64  -0.535405  [-0.55, -0.52]  0.286659  0.286552 -0.597692   0.000000e+00
# 65   0.570939    [0.56, 0.58]  0.325971  0.325870  0.648914   0.000000e+00
# 66  -0.559557  [-0.57, -0.55]  0.313104  0.313001 -0.632188   0.000000e+00
# 67  -0.612279   [-0.62, -0.6]  0.374885  0.374792 -0.712559   0.000000e+00
# 68  -0.578073  [-0.59, -0.57]  0.334168  0.334069 -0.659564   0.000000e+00
# 69  -0.521714  [-0.53, -0.51]  0.272185  0.272076 -0.578691   0.000000e+00
# 70   0.601490    [0.59, 0.61]  0.361791  0.361695  0.695479   0.000000e+00
# 71  -0.630731  [-0.64, -0.62]  0.397821  0.397731 -0.742629   0.000000e+00
# 72   0.595949    [0.58, 0.61]  0.355155  0.355058  0.686841   0.000000e+00
# 73   0.571282    [0.56, 0.58]  0.326363  0.326263  0.649424   0.000000e+00
# 74   0.629483    [0.62, 0.64]  0.396249  0.396159  0.740560   0.000000e+00
# 75  -0.557813  [-0.57, -0.55]  0.311155  0.311052 -0.629653   0.000000e+00
# 76   0.603770    [0.59, 0.61]  0.364538  0.364443  0.699058   0.000000e+00
# 77   0.455265    [0.44, 0.47]  0.207266  0.207148  0.491322   0.000000e+00
# 114 -0.344573  [-0.36, -0.33]  0.118731  0.118599 -0.359273   0.000000e+00
# 115  0.066983    [0.05, 0.08]  0.004487  0.004338  0.067083   8.782804e-15
# 116  0.164307    [0.15, 0.18]  0.026997  0.026851  0.165810   1.329794e-81
# 117  0.589019     [0.58, 0.6]  0.346944  0.346846  0.676163   0.000000e+00
# 118  0.265966    [0.25, 0.28]  0.070738  0.070599  0.272518  2.021339e-215
#
#            BF10  power
# 60          inf    1.0
# 61          inf    1.0
# 62          inf    1.0
# 63          inf    1.0
# 64          inf    1.0
# 65          inf    1.0
# 66          inf    1.0
# 67          inf    1.0
# 68          inf    1.0
# 69          inf    1.0
# 70          inf    1.0
# 71          inf    1.0
# 72          inf    1.0
# 73          inf    1.0
# 74          inf    1.0
# 75          inf    1.0
# 76          inf    1.0
# 77          inf    1.0
# 78          inf    1.0
# 79          inf    1.0
# 80          inf    1.0
# 81          inf    1.0
# 82          inf    1.0
# 83          inf    1.0
# 84          inf    1.0
# 85          inf    1.0
# 86          inf    1.0
# 87          inf    1.0
# 88          inf    1.0
# 89          inf    1.0
# 90          inf    1.0
# 91          inf    1.0
# 92          inf    1.0
# 93          inf    1.0
# 94          inf    1.0
# 95          inf    1.0
# 96          inf    1.0
# 97          inf    1.0
# 98          inf    1.0
# 99          inf    1.0
# 100         inf    1.0
# 101         inf    1.0
# 102         inf    1.0
# 103         inf    1.0
# 104         inf    1.0
# 105         inf    1.0
# 106         inf    1.0
# 107         inf    1.0
# 108         inf    1.0
# 109         inf    1.0
# 110         inf    1.0
# 111         inf    1.0
# 112         inf    1.0
# 113   1.721e+92    1.0
# 114         inf    1.0
# 115   1.245e+11    1.0
# 116    3.32e+77    1.0
# 117         inf    1.0
# 118  1.291e+211    1.0

# %% [markdown]
# <font size = 4> <b> Determine the features that have a p-value that is above the level of signifiance alpha of 0.05 </b> </font>
#
# <font size = 2> We reject the alternative hypothesis and conclude that the null hypothesis is true in this case i.e. there is no statistical significance of the correlation coefficient </font>

# %%
NO2_pearsonr_NO2[NO2_pearsonr_NO2['p-unc'] >= 0.005 ]
# Out:
# Empty DataFrame
# Columns: [X, Y, method, tail, n, r, CI95%, r2, adj_r2, z, p-unc, BF10, power]
# Index: []

# %% [markdown]
# The above tests indicate that for the BC and NO2 datasets, all the coefficients have a p-value less than 0.05, indicating that we can reject the null hypothesis and conclude that there is a <b> statistical significant relationship </b> between each feature in the dataset and the target variable. Next, we fit a linear model

# %% [markdown]
#  - Linear regression for stats
#     - VIF scores - gives a score between all feeatures/predictor variables
#     - Then do a linear regression
#     - Combine two facilities that are close to each other with similar VIF scores and take average distance
#     - After combining, do correlation test to see significance, and drop columns that have a high p-value
#     - Recalculate VIF scores again
#     - Do some type of linear regression for model - check linear regression model
#     - what are the other ways of identifying and dropping highly correlated features in feature selection?

# %% [markdown]
# Potential questions:
#
#     1) What is the probability of observing a concentration that is higher than the ambient standards for Black Carbon and NO2?

# %% [markdown]
# <b> T-test to determine whether is a significant difference between the means of two groups.</b>
#
# 1) Is there a significant difference in BC concentration for distance to highways > 4 km and less than 4 km?
# 1) Is there a significant difference in NO2 concentration for distance to highways > 4 km and less than 4 km?
