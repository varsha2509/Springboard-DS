# %%
import requests

# %%
res = requests.get('https://prettyprinted.com')

# %%
print(res)
# Out:
# <Response [200]>

# %%
## 200 - means everything was successful with the request

# %%
## 404 - A page that does not exist

# %%
print(res.status_code)
# Out:
# 200

# %%
if res:
    print('Response ok')
else:
    print('Response failed')
# Out:
# Response ok

# %%
print(res.headers) ### This returns the header of all the data
# Out:
# {'Server': 'nginx/1.14.2', 'Date': 'Sun, 15 Mar 2020 07:04:07 GMT', 'Content-Type': 'text/html', 'Last-Modified': 'Fri, 06 Mar 2020 08:00:18 GMT', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Vary': 'Accept-Encoding', 'ETag': 'W/"5e620312-2791"', 'X-Frame-Options': 'SAMEORIGIN', 'Content-Encoding': 'gzip'}

# %%
print(res.text) ### This returns all the data in text format, easy to see what it looks like

### Basically everything that you see if you hit 'view source' on a html page gets written up here
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#
#   <meta charset="utf-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">
#   <meta name="description" content="">
#   <meta name="author" content="">
#
#   <title>Pretty Printed</title>
#
#   <!-- Bootstrap core CSS -->
#   <link href="vendor/bootstrap/css/bootstrap.min.css" rel="stylesheet">
#
#   <!-- Custom fonts for this template -->
#   <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.8.2/css/all.css" integrity="sha384-oS3vJWv+0UjzBfQzYUhtDYW+Pj2yciDJxpsK1OYPAYjqT085Qq/1cq5FLXAZQ7Ay" crossorigin="anonymous">
#
#   <!-- Custom styles for this template -->
#   <link href="css/freelancer.css" rel="stylesheet">
#   <link rel="shortcut icon" href="/img/favicon.ico">
#   <link rel="stylesheet" href="css/style.css" />
#   <script>
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# ...

# %%
output = open('index.html','w')
output.write(res.text)
output.close()

# %%
#Example is to translate text from English to Spanish using Yandex
res = resquests.get(url) #url is the link to Yandex but I'm not pasting that here
API_KEY = xxxxx #Your API key from the website
params = dict(key = API_KEY, text = 'Hello',lang = 'en-es')

res = requests.get(url, params = params)

print(res.text)

# %%
## If you want the output in json instead of plain txt. The output is a dictionary
res = requests.get(url, params = params)
json = res.json()
print(json)
